# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *잠재*되어있는 latent 되어있는

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 사람이 판단
#
# 토픽 A는 음식이구나 B는 동물이구나
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 문장별 분류가 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LDA는 2가지 분포 뽑아냄 frequency기반 모델링

# %% [markdown]
# 토픽(포켓몬)에 피카츄가 들어가있을 확률을 ***베이즈추론***을 통해서 추론. 들어있을 확률(비율)을 구함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A문서: 우리집 애완동물. 먹이는 ~~~~ 동물~~~
# - 강아지 고양이 말, 토마토 양상추 등장할수있다.
#   - 고양이 100번중 40번등장 > 확률 0.4
# - 토픽1 = 동물로 만들어짐
# - 동물토픽 : 강아지 20, 고양이40, 말 20, 토마토3, 양상추7
#
#
# B문서: 농작물주제.
# - 강아지 고양이 말, 토마토 양상추 등장할수있다.
# - 토픽2 = 농작물로 만들어짐
# - 농작물토픽 : 양상추 40, 토마토50, 말 3, 강아지3, 고양이4
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 토픽이 위처럼 구성되어있어야 문서의 토픽분포가능
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 토픽의 개수 K는 사람이 직접 넣어줘야함.

# %% [markdown]
# 토픽의 단어분포(빨간상자)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 문서의 토픽분포
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 시작할때 랜덤이기때문에 문서1 친절이 토픽2로들어갈수도있음. 반복문으로 돌려가며 수정

# %% [markdown]
# 모든단어에대해 하나 고정하고 나머지보는방식으로 반복수행
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 어나 2가아니라 1로가야겠네 방식

# %% [markdown]
# 빨간색이 파란색을보고 어디로가야겠다를 결정
#
# ![image.png](data:image/png;base64,...)
