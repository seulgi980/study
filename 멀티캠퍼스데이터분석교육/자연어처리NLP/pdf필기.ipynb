# %% [markdown]
# 숫자형식으로 변환시킨다 > 레이블을 의미
#
# - 이 단어는 이 숫자야 = 심볼릭을 넘겨준다는 의미
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Word Sense = 단어의 의미
# 입으로 단어를 내뱉으면 symbolic이됨.

# %% [markdown]
# # Integer Encoding
# - 단어를 정수로바꿔서 컴퓨터에게 알려주는 방법
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# corpus에서 단어집합 뽑아내기.
# - 단어집합도 하나의 corpus가 될 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위에 번호도 맘대로붙인거고 B도 145라서 그냥 참고만하기. 틀린거몇개있음

# %% [markdown]
# # 패딩을 해야 병렬행렬연산 가능하기때문에

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 0이 뒤에붙으면 post패딩

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 0이 앞에붙으면 pre패딩

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 없다고 무조건 단어집합에 추가하면 크기가 존나커지기때문에!
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# corpus에 문장하나 추가됐다고하자

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 소고기에대한 정수mapping이 부락능한 상태.
# OOV 토큰 1로 하나 넣어주기

# %% [markdown]
# # BOW( Bag od Word)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 순서가 없어짐. 문맥을 보지 않겠다. 단어에만 집중을 하겠다.
# - 단어의 '빈도수'에만 집중을 하겠다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # DTM 문장마다 등장한 단어의 횟수 세어주기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # TF_IDF 로 중요도까지 계산가능
# - tf = dtm

# %% [markdown]
# ![image.png](data:image/png;base64,...)
