# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 단방향 RNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 나는 : h1
#
# 나는 추워서 : h2 까지밖에모름 추워서 뭘했는데?
#
# 나는 추워서 패딩을 : h3

# %% [markdown]
# ## 양방향 RNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 빈칸 예측 가능
# - 앞 뒤 문맥을 같이 파악할 수 있다.
# - 나는 --- 보단
# - 나는 --- 패딩을 입었다가 빈칸에 뭐가 들어갈지 더쉽게예측가능
# - 미래에 대한 정보까지 같이주는느낌
# - loss를 좀더빨리 떨어뜨릴수있다.
