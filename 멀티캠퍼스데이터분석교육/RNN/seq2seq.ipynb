# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 참고 : RNN으로 써놨지만 성능 문제로 인해 실제로는 바닐라 RNN이 아니라 LSTM 셀 또는 GRU 셀들로 구성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # context vector
# - 인코더의 제일 마지막 hidden state가 context vector가됨⭐
# - 문장의 의미를 담고있다. 벡터로 변환 형태로

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## context vector가 decoder의 초기 hidden state가 된다! 0으로 시작하는게 아님

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ^y1이 다음상태 입력값 y1으로 사용됨⭐
# - 예측한걸 다음상태의 입력으로!!
#
# 디코더는 초기 입력으로 문장의 시작을 의미하는 심볼 <sos>가 들어갑니다. 디코더는 <sos>가 입력되면, 다음에 등장할 확률이 높은 단어를 예측합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 마지막 예측값은 EOS(end of sequence)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 방금같은 예시는 bilingual corpus 말뭉치 2개필요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## decoder의 상세 구조
# - 앞의예제는 $h_t$ --> $h_{t+1}$이어야하는데 구조만보게 다시그림. 위의예제잊어~
# - $y_t$도 t-1이라고쓰는경우도있음 그냥 구조만 이해하기 작동방식만

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $v^{dec}$는 decoder의 vocabsize

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 현재 상태 hidden state에 대한 단어 유사도가 나온다

# %% [markdown]
# 내적은 유사도느낌임
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 나는 너를까지 왔다 >> 사랑해 단어와 유사도가 가장 높으니 사랑해 예측

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 예시!!

# %% [markdown]
# ^y1이 다음상태 입력값 y1으로 사용됨⭐
# - 예측한걸 다음상태의 입력으로!! 무지중요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이제 4 사랑해 벡터가 다음스텝의 입력으로 들어간다!!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 월요일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 데이터셋 구조

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# m,n 은 다를수도
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 내가 생성해야할 문장의 맨앞과 맨뒤는 SOS, EOS라는 스페셜 토큰이 있어야함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 원핫 벡터로 되어있음 >  vocab size⭐⭐

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 노랑주황표는 embedding벡터라 숫자들채워져있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 입력데이터들의 shape

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $y_0$ 부분이 예측값이아니라 초기값이 들어가기때문에 인덱싱 짜증남
# - 첫항만 다른 느낌

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 틸다 써서 2가지로 표현가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
