# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 모델은 i love you에 대해 처음에 '밥을'을 예측해서 loss가 크케나왔다.
#
# 빨리 수정하기위해서.
# 너는 밥을을 예측했지만 실제로는 나는이었지롱.
#
# loss를 증가시켜서 더빨리 loss가 감소하는 학습을 할 수 있도록 해줌.
#
# 강제로 입력에'나는',을 입력해줌
# - 훈련을 효율적으로 빠르게 할 수 있도록 도와주는 기법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 빨강 : 예측
#
# 주황 : 정답넣어주기 정답은 사실 이거였어

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # TEST할땐 교사강요 쓰면안됨!! 훈련할때만 써야함

# %% [markdown]
# ## Input Feeding(옵션)
# - 예측+ 정답을 같이 엮어서 올려줌
# - 잊어버렸었던 예측값도 적당히 기억할수있도록 해주는거

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 교사강요만 하다보면 예측값은 쓸모가없네? 라고 하는 학습이 되어버릴수도 있기 때문에 예측+정답을 concat해줌

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# shape을 맞춰주기위해 곱해주는 $W_{concat}$

# %% [markdown]
# 예시) 좀 관련이된 이어진 문제들 푼다고해보자
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 코드로구현

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
