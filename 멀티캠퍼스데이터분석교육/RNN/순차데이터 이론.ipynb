# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# language model 은 확률(count)기반으로 다음에 나올 단어를 판별
# - 단점 : 새로본 단어엔 대응을 할 수 없음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Memory system
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 두루마리 휴지말은거 ↑
#
# h = hidden states 감춰진 상태, 이전 기억

# %% [markdown]
# 오른쪽 = 두루마리 휴지 펼친거
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - x들은 임베딩으로 얻어질거
# - RNN cell의 연산보자. 뉴런이 들어있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5차원짜리넣어서 뉴런3개면
#
#  (,5) 가중치(5,3) = 결과 (,3)

# %% [markdown]
# 근데 앞에서 전해진 h(n-1)도 있다. 거기에 해당하는 가중치 W(hh)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# rnn은 출력의 종류가 2개이다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 단일출력 그림 y가 하나
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 다중출력엔 softmax를 단일출력엔 tanh를 많이쓸겨!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # BoW와 별개의 개념이 아니라 Bow를 실제로 활용하기 위해 행렬의 형식으로 표현한 거라 생각하면 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# dim2로 그려보자 예시로. 비슷한거끼리 그려지겠징 반대면 반대방향

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 단어 1개가 여러가지 의미를 가질수있따. embedding dimension을 늘린다.

# %% [markdown]
# # 임베딩 예시
# -단어를 벡터로 풀어낸거 (관련있게)
# - 컴퓨터가 정보를 가지게함
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 보라 : 먹는거, 배랑 사과랑 비슷하다
# 빨강 : 타는거 배, 타다, 목적지 이동,
#
# 차에는 빨간차(타는거), 초록차(마시는거)
#
# M이 커질수록 단어를 복잡하게 생각.
# 차: 마시는거, 빼기, 타는거, ...
#
# '차를' > 나오면 연관성있는벡터 마신다(초록)or 탄다(빨강)이 나올수있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# projection하면 5213벡터가 쭈루루룩 쌓임.
# - 순서가 만들어짐!!!

# %% [markdown]
# y는 빼고 RNN그려보기
#
# ![image.png](data:image/png;base64,...)
