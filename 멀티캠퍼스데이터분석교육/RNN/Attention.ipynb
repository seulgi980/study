# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 어텐션 = 집중!!!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# seq2seq의 단점 : 너를 을 뽑기위해 의지할게 나는밖에없더..

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 너를이랑 I가 얼마나 비슷한지
#
# 너를이랑 Iove가 얼마나 비슷한지
#
# 너를이랑 you가 얼마나 비슷한지
#
# ...
#
# # 유사도(energy)파악!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 초록색은 embedding vector임!!
#
# ###합의 결과물을 Attention Value라고함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You에 집중할 수 있게됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 파란색 = attention value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
