# %%
# !pip install fake_useragent
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests
from fake_useragent import UserAgent
import pandas as pd

maximum = 0
page = 1
num = 1 #1부터돌기

URL = f"https://www.musinsa.com/categories/item/002023?d_cat_cd=002023&brand=&list_kind=small&sort=pop_category&sub_sort=&page={num}&display_cnt=90&group_sale=&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure="
headers = {"user-agent": UserAgent().chrome}
  
response = requests.get(URL, headers=headers)
page = response.content
soup = BeautifulSoup(page, 'html.parser')

# %%
for i in range(1,soup.select_one(".pagingNumber").text.split()[0]): # =40페이지

  URL = f"https://www.musinsa.com/categories/item/002023?d_cat_cd=002023&brand=&list_kind=small&sort=pop_category&sub_sort=&page={i}&display_cnt=90&group_sale=&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure="
  headers = {"user-agent": UserAgent().chrome}
  
  response = requests.get(URL, headers=headers)
  page = response.content
  soup = BeautifulSoup(page, 'html.parser')

  fin_list = soup.select("#searchList > li")
  brand_list = []

  for fin in fin_list:
    brand = fin.select_one(".item_title > a").text
    brand_list.append(brand)


  print(brand_list)
# Out:
# ['스파오', '커버낫', '그루브라임', '커버낫', '무신사 스탠다드', '예일', '커버낫', '커버낫', '커버낫', '커버낫', '리', '와릿이즌', '후아유', '코드그라피', '무신사 스탠다드', '후아유', '코드그라피', '에프씨엠엠', '내셔널지오그래픽', '내셔널지오그래픽', '코드그라피', '리', '커버낫', '예일', '무신사 스탠다드', '에프씨엠엠', '언리미트', '코드그라피', '커버낫', '리', '에프씨엠엠', '에프씨엠엠', '커버낫', '커버낫', '커버낫', '무신사 스탠다드', '지프', '와릿이즌', '무신사 스탠다드', '무신사 스탠다드', '지프', '무신사 스탠다드', '와릿이즌', '예일', '커버낫', '무신사 스탠다드', '무신사 스탠다드', '후아유', '파마컬렉션', '에프씨엠엠', '커버낫', '무신사 스탠다드', '파마컬렉션', '아디다스', '커버낫', '무신사 스탠다드', '무신사 스탠다드', '커버낫', '내셔널지오그래픽', '본챔스', '내셔널지오그래픽', '라퍼지스토어', '예일', '무신사 스탠다드', '무신사 스탠다드', '내셔널지오그래픽', '무신사 스탠다드', '와릿이즌', '커버낫', '예일', '내셔널지오그래픽', '내셔널지오그래픽', '무신사 스탠다드', '와릿이즌', '커버낫', '라퍼지스토어', '예일', '와릿이즌', '그루브라임', '본챔스', '커버낫', '예일', '블러프', '아디다스', '예일', '라퍼지스토어', '코드그라피', '잠뱅이', '잠뱅이', '잠뱅이']
# ...

# %%
result = pd.DataFrame({
    "브랜드": brand_list})

result

# %%
soup.select_one(".pagingNumber").text.split()[0]
# Out:
# '40'

# %%
for i in range(1,10): 

  URL = f"https://www.musinsa.com/categories/item/002023?d_cat_cd=002023&brand=&list_kind=small&sort=pop_category&sub_sort=&page={i}&display_cnt=90&group_sale=&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure="
  headers = {"user-agent": UserAgent().chrome}
  
  response = requests.get(URL, headers=headers)
  page = response.content
  soup = BeautifulSoup(page, 'html.parser')

  fin_list = soup.select("#searchList > li")
  title_list = []

  for fin in fin_list:
    title = fin.select_one(".list_info").text.strip()
    title_list.append(title)
    


  print(title_list)
# Out:
# ['베이직 퍼플리스 집업_SPFZC4TU01', '플리스 집업 자켓 블랙', '[패키지] FLEECE HALF ZIP-UP [LRPWCF...', '리버시블 쉐르파 집업 자켓 아이보리', '샤기 플리스 집업 재킷 [블랙]', 'EMBROIDERY UNIVERSITY DAN FLEECE...', '플리스 카라리스 자켓 블랙', '리버시블 카라리스 쉐르파 집업 자켓 아이보리', '플리스 집업 자켓 아이보리', '리버시블 쉐르파 후디 집업 자켓 아이보리', '트위치로고 폴라플리스 집업자켓 블랙', '엔젤 플리스 집업 아이보리', '리버서블 후드웜업 [3color] WHJJC4T01U', '[호시 PICK] 헤비 보아 CGP 더플 플리스 점퍼_3c...', '오버사이즈 폴라 플리스 하이넥 재킷 [블랙]', '리버서블 후드웜업 [2color] WHJJC4T01U', '[호시 PICK] 헤비 보아 CGP 플리스 점퍼_4colo...', '11/4 배송 \n                  \n                  \n                  [아이브 레이 PICK] 빅로고 보아 플리스 점퍼 - 그레...', 'N224MFJ910 남성 코스토니 플리스 뽀글이 후드 풀집...', 'N224UFJ901 오르카 스탠다드 플리스 집업 CARBO...', '[호시 PICK] 헤비 보아 CGP 플리스 후드 집업 점퍼...', '트위치로고 폴라플리스 집업자켓 아이보리', '리버시블 쉐르파 집업 자켓 블랙', 'EMBROIDERY UNIVERSITY DAN FLEECE...', '샤기 플리스 집업 재킷 [크림]', '[아이브 레이 PICK] 빅로고 보아 플리스 점퍼 - 블랙...', '베이직 플리스 자켓 (U00DTJK59)', '헤비 보아 웜업 플리스  자켓 가디건_블랙', '플리스 카라리스 자켓 아이보리', '트위치로고 폴라플리스 집업자켓 네이비', '[아이브 레이 PICK] 빅로고 보아 플리스 점퍼 - 샌드...', '클럽 스탠다드 플리스 집업 자켓 - 블랙',
# ...
