# %% [markdown]
# # Type 함수 사용

# %%
a = 1
print(a)
# Out:
# 1

# %%
a = 2
print(a)
# Out:
# 2

# %%
a = 1
type(a)
# Out:
# int

# %%
a = 3.14
type(a)
# Out:
# float

# %%
a = "제 이름은 한슬기입니다."
type(a)
# Out:
# str

# %%
a = 3 < 2
a
# Out:
# False

# %%
type(a)
# Out:
# bool
