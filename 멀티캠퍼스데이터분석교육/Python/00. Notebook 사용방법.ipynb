# %%
a = 1
b = 2
a+b
# Out:
# 3

# %% [markdown]
# # LaTex
# 마크다운에서 수식을 적고 싶을 때 활용
# - 인라인 수식
#   - 인라인 수식은 마크다운 작성 중간에 들어가는 수식. $a=1, b=2, a+b=3$
# - 블록 수식
#   - 하나의 칸을 모두 사용하여 수식을 작성
# $$
# a=1, b=2, a+b=3
# $$
#
# $$
# f(x) = 2x+1
# $$
